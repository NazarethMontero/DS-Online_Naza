# %% [markdown]
# # **Kaggle – DataTops®**
# Tu TA ha decidido cambiar de aires y, por eso, ha comprado una tienda de portátiles. Sin embargo, su única especialidad es Data Science, por lo que ha decidido crear un modelo de ML para establecer los mejores precios.
#
# ¿Podrías ayudar a tu profe a mejorar ese modelo?

# %% [markdown]
# ## Aspectos importantes
# - Última submission:
#     - Mañana: 17 de febrero a las 5pm
#     - Tarde: 19 de febrero a las 5pm
# - **Enlace de la competición**: https://www.kaggle.com/t/c5cc87b50c4b4770bdc8f5acbe15577d
# - **Requisito**: Estar registrado en [Kaggle](https://www.kaggle.com/)

# %% [markdown]
# ## Métrica:
# El error cuadrático medio (RMSE, por sus siglas en inglés) es una medida de la desviación estándar de los residuos (errores de predicción). Los residuos representan la diferencia entre los valores observados y los valores predichos por el modelo. El RMSE indica qué tan dispersos están estos errores: cuanto menor es el RMSE, más cercanas están las predicciones a los valores reales. En otras palabras, el RMSE mide qué tan bien se ajusta la línea de regresión a los datos.
#
#
# $$ RMSE = \sqrt{\frac{1}{n}\Sigma_{i=1}^{n}{\Big(\frac{d_i -f_i}{\sigma_i}\Big)^2}}$$

# %% [markdown]
# ## 1. Librerías

# %%
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import urllib.request

# %% [markdown]
# ## 2. Datos

# %%
# Para que funcione necesitas bajarte los archivos de datos de Kaggle
df = pd.read_csv("./data/train.csv", index_col="laptop_ID")

# %%
df.drop("id", axis = 1, inplace = True)

# %% [markdown]
# ### 2.1 Exploración de los datos

# %% [markdown]
# Pese a que parece que los datos están limpios, habrá que revisar si la información no está sucia. El laptop_ID son valores únicos que podrían pasarse a índice (HECHO). Sample sumbission es un ejemplo de como debe ser unestra subida de información (columna id y price/euros)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 1002 to 1313
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    object
#  1   Product           912 non-null    object
#  2   TypeName          912 non-null    object
#  3   Inches            912 non-null    float64
#  4   ScreenResolution  912 non-null    object
#  5   Cpu               912 non-null    object
#  6   Ram               912 non-null    object
#  7   Memory            912 non-null    object
#  8   Gpu               912 non-null    object
#  9   OpSys             912 non-null    object
#  10  Weight            912 non-null    object
#  11  Price_euros       912 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 92.6+ KB

# %%
df.head()
# Out:
#            Company                     Product   TypeName  Inches  \
# laptop_ID
# 1002          Dell               Inspiron 5567   Notebook    15.6
# 867           Asus  X541NA (N4200/4GB/1TB/W10)   Notebook    15.6
# 966        Toshiba           Portege Z30-C-1CW   Notebook    13.3
# 767           Dell                Alienware 17     Gaming    15.6
# 1241          Dell              Latitude E7270  Ultrabook    12.5
#
#                           ScreenResolution  \
# laptop_ID
# 1002                              1366x768
# 867                               1366x768
# 966                      Full HD 1920x1080
# 767        IPS Panel 4K Ultra HD 3840x2160
# 1241       Full HD / Touchscreen 1920x1080
#
#                                             Cpu   Ram                Memory  \
# laptop_ID
# 1002                 Intel Core i7 7500U 2.7GHz   8GB               1TB HDD
# 867        Intel Pentium Quad Core N4200 1.1GHz   4GB               1TB HDD
# 966                  Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 767                 Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 1241                 Intel Core i5 6300U 2.4GHz   8GB             256GB SSD
#
#                                Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 1002            AMD Radeon R7 M445  Windows 10  2.36kg       749.00
# 867          Intel HD Graphics 505  Windows 10     2kg       449.00
# 966          Intel HD Graphics 520   Windows 7   1.2kg      1460.00
# 767        Nvidia GeForce GTX 1070  Windows 10  4.42kg      2868.99
# 1241         Intel HD Graphics 520   Windows 7  1.26kg      1713.37

# %%
df.tail()
# Out:
#            Company                Product            TypeName  Inches  \
# laptop_ID
# 973           Acer  Chromebook C738T-C2EJ  2 in 1 Convertible    11.6
# 1018       Toshiba      Portege Z30-C-16H            Notebook    13.3
# 1071          Acer         Aspire ES1-523            Notebook    15.6
# 965           Dell          Latitude 7480           Ultrabook    14.0
# 1313          Dell          Inspiron 3567            Notebook    15.6
#
#                          ScreenResolution  \
# laptop_ID
# 973        IPS Panel Touchscreen 1366x768
# 1018                    Full HD 1920x1080
# 1071                             1366x768
# 965                     Full HD 1920x1080
# 1313                             1366x768
#
#                                             Cpu  Ram              Memory  \
# laptop_ID
# 973        Intel Celeron Dual Core N3060 1.6GHz  4GB  32GB Flash Storage
# 1018                 Intel Core i5 6200U 2.3GHz  4GB           128GB SSD
# 1071                  AMD A8-Series 7410 2.2GHz  8GB             1TB HDD
# 965                  Intel Core i7 7600U 2.8GHz  8GB           256GB SSD
# 1313                 Intel Core i7 7500U 2.7GHz  8GB             1TB HDD
#
#                              Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 973        Intel HD Graphics 400   Chrome OS  1.25kg       389.00
# 1018       Intel HD Graphics 520  Windows 10   1.2kg      1195.00
# 1071               AMD Radeon R5  Windows 10   2.4kg       449.00
# 965        Intel HD Graphics 620  Windows 10  1.36kg      1775.00
# 1313          AMD Radeon R5 M430       Linux   2.3kg       805.99

# %%
df.describe()
# Out:
#            Inches  Price_euros
# count  912.000000   912.000000
# mean    15.011404  1108.122873
# std      1.411744   714.597741
# min     10.100000   174.000000
# 25%     14.000000   589.000000
# 50%     15.600000   949.000000
# 75%     15.600000  1458.500000
# max     18.400000  6099.000000

# %% [markdown]
# ### 2.3 Definir X e y

# %%
X = df.drop(['Price_euros'], axis=1)
y = df['Price_euros'].copy()
X.shape
# Out:
# (912, 11)

# %%
y.shape #La x es un data frame
# Out:
# (912,)

# %% [markdown]
# ### 2.4 Dividir X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
X_train
# Out:
#           Company                                    Product  TypeName  \
# laptop_ID
# 41           Asus  X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux)  Notebook
# 127          Acer                                   Aspire 3  Notebook
# 1243         Asus         X540SA-RBPDN09 (N3710/4GB/1TB/W10)  Notebook
# 105          Dell                              Inspiron 3576  Notebook
# 578            HP             14-am079na (N3710/8GB/2TB/W10)  Notebook
# ...           ...                                        ...       ...
# 267            HP                                ProBook 450  Notebook
# 610           MSI                                 Laptop MSI    Gaming
# 1026           HP                              Elitebook 840  Notebook
# 363          Dell                              Inspiron 7577    Gaming
# 169           MSI                                 GE63VR 7RE    Gaming
#
#            Inches             ScreenResolution  \
# laptop_ID
# 41           15.6            Full HD 1920x1080
# 127          15.6                     1366x768
# 1243         15.6                     1366x768
# 105          15.6            Full HD 1920x1080
# 578          14.0                     1366x768
# ...           ...                          ...
# 267          15.6  IPS Panel Full HD 1920x1080
# 610          17.3            Full HD 1920x1080
# 1026         14.0            Full HD 1920x1080
# 363          15.6            Full HD 1920x1080
# 169          15.6  IPS Panel Full HD 1920x1080
#
#                                             Cpu   Ram                Memory  \
# laptop_ID
# 41                     Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 127                     AMD A9-Series 9420 3GHz   4GB             256GB SSD
# 1243       Intel Pentium Quad Core N3710 1.6GHz   4GB               1TB HDD
# 105                  Intel Core i5 8250U 1.6GHz   8GB               1TB HDD
# 578        Intel Pentium Quad Core N3710 1.6GHz   8GB               2TB HDD
# ...                                         ...   ...                   ...
# 267                  Intel Core i5 8250U 1.6GHz   4GB             500GB HDD
# 610                 Intel Core i7 6820HK 2.7GHz  16GB  128GB SSD +  1TB HDD
# 1026                 Intel Core i5 7200U 2.5GHz   4GB             256GB SSD
# 363                 Intel Core i5 7300HQ 2.5GHz   8GB               1TB HDD
# 169                 Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                                Gpu       OpSys  Weight
# laptop_ID
# 41           Intel HD Graphics 620       Linux     2kg
# 127                  AMD Radeon R5  Windows 10   2.1kg
# 1243         Intel HD Graphics 405  Windows 10  2.65kg
# 105                 AMD Radeon 520       Linux   2.2kg
# 578          Intel HD Graphics 405  Windows 10  1.94kg
# ...                            ...         ...     ...
# 267          Intel HD Graphics 620  Windows 10   2.1kg
# 610        Nvidia GeForce GTX 970M  Windows 10  4.14kg
# 1026         Intel HD Graphics 620  Windows 10  1.48kg
# 363        Nvidia GeForce GTX 1050  Windows 10  2.65kg
# 169        Nvidia GeForce GTX 1060  Windows 10   2.4kg
#
# [729 rows x 11 columns]

# %%
y_train
# Out:
# laptop_ID
# 41       389.0
# 127      451.0
# 1243     309.0
# 105      647.0
# 578      389.0
#          ...
# 267      722.0
# 610     2199.0
# 1026    1590.0
# 363      999.0
# 169     1799.0
# Name: Price_euros, Length: 729, dtype: float64

# %% [markdown]
# ## 3. Procesado de datos

# %% [markdown]
# Nuestro target es la columna `Price_in_euros`

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 4. Modelado

# %% [markdown]
# ### 4.1 Baseline de modelos

# %% [markdown]
# ### 4.2 Sacar métricas, valorar los modelos
#
# Recuerda que en la competición se va a evaluar con la métrica de ``RMSE``.

# %% [markdown]
# ### 4.3 Optimización (up to you 🫰🏻)

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ## Una vez listo el modelo, toca predecir ``test.csv``

# %% [markdown]
# **RECUERDA: APLICAR LAS TRANSFORMACIONES QUE HAYAS REALIZADO EN `train.csv` a `test.csv`.**
#
#
# Véase:
# - Estandarización/Normalización
# - Eliminación de Outliers
# - Eliminación de columnas
# - Creación de columnas nuevas
# - Gestión de valores nulos
# - Y un largo etcétera de técnicas que como Data Scientist hayas considerado las mejores para tu dataset.

# %% [markdown]
# ## 1. Carga los datos de `test.csv` para predecir.

# %%
X_pred = pd.read_csv("./data/test.csv")
X_pred.head()

# %%
X_pred.tail()

# %%
X_pred.info()

# %% [markdown]
#  ## 2. Replicar el procesado para ``test.csv``

# %%
X_pred

# %%
predictions_submit = model.predict(X_pred)
predictions_submit

# %% [markdown]
# **¡OJO! ¿Por qué me da error?**

# %% [markdown]
# IMPORTANTE:
#
# - SI EL ARRAY CON EL QUE HICISTEIS `.fit()` ERA DE 4 COLUMNAS, PARA `.predict()` DEBEN SER LAS MISMAS
# - SI AL ARRAY CON EL QUE HICISTEIS `.fit()` LO NORMALIZASTEIS, PARA `.predict()` DEBÉIS NORMALIZARLO
# - TODO IGUAL SALVO **BORRAR FILAS**, EL NÚMERO DE ROWS SE DEBE MANTENER EN ESTE SET, PUES LA PREDICCIÓN DEBE TENER **391 FILAS**, SI O SI

# %% [markdown]
# **Entonces, si al cargar los datos de ``train.csv`` usaste `index_col=0`, ¿tendré que hacer lo también para el `test.csv`?**

# %%
# ¿Qué opináis?
# ¿Sí, no?

# %% [markdown]
# ![wow.jpeg](attachment:wow.jpeg)

# %% [markdown]
# ## 3. **¿Qué es lo que subirás a Kaggle?**

# %% [markdown]
# **Para subir a Kaggle la predicción esta tendrá que tener una forma específica.**
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %%
sample = pd.read_csv("data/sample_submission.csv")

# %%
sample.head()

# %%
sample.shape

# %% [markdown]
# ## 4. Mete tus predicciones en un dataframe llamado ``submission``.

# %%
#¿Cómo creamos la submission?
submission = pd.DataFrame()

# %%
submission.head()

# %%
submission.shape

# %% [markdown]
# ## 5. Pásale el CHEQUEADOR para comprobar que efectivamente está listo para subir a Kaggle.

# %%
def chequeador(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.

    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.

    Si no, LEE EL MENSAJE Y HAZLE CASO.

    Si aún no:
    - apaga tu ordenador,
    - date una vuelta,
    - enciendelo otra vez,
    - abre este notebook y
    - leelo todo de nuevo.
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.laptop_ID.all() == sample.laptop_ID.all():
                print("You're ready to submit!")
                df_to_submit.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://www.mihaileric.com/static/evaluation-meme-e0a350f278a36346e6d46b139b1d0da0-ed51e.jpg", "gfg.png")
                img = Image.open("gfg.png")
                img.show()
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("\nMensaje secreto del TA: No me puedo creer que después de todo este notebook hayas hecho algún cambio en las filas de `test.csv`. Lloro.")

# %%
chequeador(submission)
